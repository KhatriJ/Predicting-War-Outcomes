# %% [markdown]
# #                            Predicting Conflict Outcomes
# by Jigar Khatri

# %% [markdown]
# # Explanation of Project
# - With this project I am looking to test out a few machine learing models by using them to predict conflict outcomes.
# - The conflicts are conventional interstate conflicts in a dyadic context (states vs states with two sides).
# - I am looking to examine how differences in several areas impact conflict outcomes.

# %% [markdown]
# # Importing the Data and Conducting Initial Exploration

# %%
import pandas as pd
import numpy as np

# %%
# %load_ext blackcellmagic

# %%
pd.options.display.max_columns=99

# %%
df = pd.read_csv("directed_dyadic_war.csv")  # Load the first data set.

# %%
df.shape  # Get an idea of how big the dataset is
# Out:
# (1364, 23)

# %%
df.info()  # See what types of data we have to work with and if there are any missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1364 entries, 0 to 1363
# Data columns (total 23 columns):
# warnum          1364 non-null int64
# disno           1364 non-null int64
# dyindex         1364 non-null float64
# statea          1364 non-null int64
# stateb          1364 non-null int64
# warstrtmnth     1364 non-null int64
# warstrtday      1364 non-null int64
# warstrtyr       1364 non-null int64
# warendmnth      1364 non-null int64
# warenday        1364 non-null int64
# warendyr        1364 non-null int64
# year            1364 non-null int64
# warolea         1364 non-null int64
# waroleb         1364 non-null int64
# wardyadrolea    1364 non-null int64
# wardyadroleb    1364 non-null int64
# outcomea        1362 non-null float64
# batdtha         1350 non-null float64
# batdthb         1350 non-null float64
# changes_1       85 non-null float64
# changes_2       0 non-null float64
# batdths         1348 non-null float64
# durindx         1364 non-null int64
# dtypes: float64(7), int64(16)
# memory usage: 245.2 KB

# %%
df.head()  # Take a peek at the data
# Out:
#    warnum  disno  dyindex  statea  stateb  warstrtmnth  warstrtday  warstrtyr  \
# 0       1     89   89.001     220     230            4           7       1823
# 1       1     89   89.001     230     220            4           7       1823
# 2       4    189  189.001     365     640            4          30       1828
# 3       4    189  189.001     365     640            4          30       1828
# 4       4    189  189.001     640     365            4          30       1828
#
#    warendmnth  warenday  warendyr  year  warolea  waroleb  wardyadrolea  \
# 0           9        30      1823  1823        1        3             1
# 1           9        30      1823  1823        3        1             3
# 2           8        19      1829  1828        1        3             1
# 3           8        19      1829  1829        1        3             1
# 4           8        19      1829  1828        3        1             3
#
#    wardyadroleb  outcomea  batdtha  batdthb  changes_1  changes_2   batdths  \
# 0             3       1.0    400.0    600.0        NaN        NaN    1000.0
# 1             1       3.0    600.0    400.0        NaN        NaN    1000.0
# 2             3       1.0  80000.0  50000.0        NaN        NaN  130000.0
# 3             3       1.0  80000.0  50000.0        NaN        NaN  130000.0
# 4             1       3.0  50000.0  80000.0        NaN        NaN  130000.0
#
#    durindx
# 0        1
# 1        1
# 2        1
# 3        2
# 4        2

# %% [markdown]
# # Data Cleaning,Transforming, and Intial Exploration

# %%
df['warendyr'].describe() # Do this for every column to see. The max value for the 'warendyr' column makes no sense.
# Out:
# count     1364.000000
# mean      1970.607038
# std        806.189591
# min       1823.000000
# 25%       1918.000000
# 50%       1945.000000
# 75%       1953.000000
# max      19118.000000
# Name: warendyr, dtype: float64

# %%
df.loc[df["warendyr"] == 19118, "warendyr"] = 1918  # Converts 19118 to 1918.

# %%
df["warendyr"].describe()  # As we can see, the problem is solved.
# Out:
# count    1364.000000
# mean     1932.777126
# std        36.616834
# min      1823.000000
# 25%      1918.000000
# 50%      1944.000000
# 75%      1953.000000
# max      2003.000000
# Name: warendyr, dtype: float64

# %%
# Eventually we want to subtract datetime objects to get the length of conflicts. I begin that process by creating columns
# with dates as strings.
df["War_Start_Month_Str"] = df["warstrtmnth"].astype(str)
df["War_Start_Day_Str"] = df["warstrtday"].astype(str)
df["War_Start_Year_Str"] = df["warstrtyr"].astype(str)

# %%
df.dtypes
# Out:
# warnum                   int64
# disno                    int64
# dyindex                float64
# statea                   int64
# stateb                   int64
# warstrtmnth              int64
# warstrtday               int64
# warstrtyr                int64
# warendmnth               int64
# warenday                 int64
# warendyr                 int64
# year                     int64
# warolea                  int64
# waroleb                  int64
# wardyadrolea             int64
# wardyadroleb             int64
# outcomea               float64
# batdtha                float64
# batdthb                float64
# changes_1              float64
# changes_2              float64
# batdths                float64
# durindx                  int64
# War_Start_Month_Str     object
# War_Start_Day_Str       object
# War_Start_Year_Str      object
# dtype: object

# %%
df["Dash"] = "-"
df["Dash2"] = "-"  # add columns with dashes to help make datetime objects.

# %%
df.dtypes
# Out:
# warnum                   int64
# disno                    int64
# dyindex                float64
# statea                   int64
# stateb                   int64
# warstrtmnth              int64
# warstrtday               int64
# warstrtyr                int64
# warendmnth               int64
# warenday                 int64
# warendyr                 int64
# year                     int64
# warolea                  int64
# waroleb                  int64
# wardyadrolea             int64
# wardyadroleb             int64
# outcomea               float64
# batdtha                float64
# batdthb                float64
# changes_1              float64
# changes_2              float64
# batdths                float64
# durindx                  int64
# War_Start_Month_Str     object
# War_Start_Day_Str       object
# War_Start_Year_Str      object
# Dash                    object
# Dash2                   object
# dtype: object

# %%
# Creates a new column by adding the columns with the dates as strings and the columns that contain dashes.
df["WarSDate"] = df[
    ["War_Start_Month_Str", "Dash", "War_Start_Day_Str", "Dash2", "War_Start_Year_Str"]
].sum(axis=1)

# %%
df["War_Start_DT"] = pd.to_datetime(
    df["WarSDate"]
)  # Converts string column into datetime column

# %%
df["War_End_Month_Str"] = df["warendmnth"].astype(str)  # Repeats process for end dates
df["War_End_Day_Str"] = df["warenday"].astype(str)
df["War_End_Year_Str"] = df["warendyr"].astype(str)

# %%
df["WarEndDate"] = df[
    ["War_End_Month_Str", "Dash", "War_End_Day_Str", "Dash2", "War_End_Year_Str"]
].sum(axis=1)
# Create string column

# %%
df["W_End_Dt"] = pd.to_datetime(
    df["WarEndDate"]
)  # Create datetime column for War end date

# %%
df.dtypes
# Out:
# warnum                          int64
# disno                           int64
# dyindex                       float64
# statea                          int64
# stateb                          int64
# warstrtmnth                     int64
# warstrtday                      int64
# warstrtyr                       int64
# warendmnth                      int64
# warenday                        int64
# warendyr                        int64
# year                            int64
# warolea                         int64
# waroleb                         int64
# wardyadrolea                    int64
# wardyadroleb                    int64
# outcomea                      float64
# batdtha                       float64
# batdthb                       float64
# changes_1                     float64
# changes_2                     float64
# batdths                       float64
# durindx                         int64
# War_Start_Month_Str            object
# War_Start_Day_Str              object
# War_Start_Year_Str             object
# Dash                           object
# Dash2                          object
# WarSDate                       object
# War_Start_DT           datetime64[ns]
# War_End_Month_Str              object
# War_End_Day_Str                object
# War_End_Year_Str               object
# WarEndDate                     object
# W_End_Dt               datetime64[ns]
# dtype: object

# %%
# Take the difference between the dates to get the length of the conflict.
df["War_Length"] = df["W_End_Dt"] - df["War_Start_DT"]

# %%
df["diff_in_days"] = df[
    "War_Length"
].dt.days  # Convert length into days to get a more precise answer

# %%
df["diff_in_days"].describe()
# A conflict length can't have a negative value so we know something is fishy.
# Out:
# count    1364.000000
# mean      936.939150
# std       825.222401
# min      -227.000000
# 25%       199.000000
# 50%       889.000000
# 75%      1346.000000
# max      3734.000000
# Name: diff_in_days, dtype: float64

# %%
df.loc[
    df["diff_in_days"] < 0
].head()  # If you look at dataset the dates appear to be misplaced.
# Out:
#      warnum  disno  dyindex  statea  stateb  warstrtmnth  warstrtday  \
# 286     106    257   257.03       2     300           24          10
# 287     106    257   257.03     300       2           24          10
#
#      warstrtyr  warendmnth  warenday  warendyr  year  warolea  waroleb  \
# 286       1918           3        11      1918  1918        4        2
# 287       1918           3        11      1918  1918        2        4
#
#      wardyadrolea  wardyadroleb  outcomea    batdtha    batdthb  changes_1  \
# 286             1             3       1.0   116516.0  1200000.0        NaN
# 287             3             1       3.0  1200000.0   116516.0        NaN
#
#      changes_2    batdths  durindx War_Start_Month_Str War_Start_Day_Str  \
# 286        NaN  1316516.0        1                  24                10
# 287        NaN  1316516.0        1                  24                10
#
#     War_Start_Year_Str Dash Dash2    WarSDate War_Start_DT War_End_Month_Str  \
# 286               1918    -     -  24-10-1918   1918-10-24                 3
# 287               1918    -     -  24-10-1918   1918-10-24                 3
#
#     War_End_Day_Str War_End_Year_Str WarEndDate   W_End_Dt War_Length  \
# 286              11             1918  3-11-1918 1918-03-11  -227 days
# 287              11             1918  3-11-1918 1918-03-11  -227 days
#
#      diff_in_days
# 286          -227
# 287          -227

# %%
df = df.loc[df["diff_in_days"] >= 0]

# %%
df['diff_in_days'].describe()
# Out:
# count    1362.000000
# mean      938.648311
# std       824.620512
# min         0.000000
# 25%       199.250000
# 50%       889.000000
# 75%      1346.000000
# max      3734.000000
# Name: diff_in_days, dtype: float64

# %%
df.describe()
# Out:
#             warnum        disno      dyindex       statea       stateb  \
# count  1362.000000  1362.000000  1362.000000  1362.000000  1362.000000
# mean    125.268722   772.506608   772.540370   453.311307   453.311307
# std      45.687528  1023.977286  1023.961692   253.216818   253.216818
# min       1.000000     8.000000     8.001000     2.000000     2.000000
# 25%     106.000000   179.000000   179.001000   255.000000   255.000000
# 50%     139.000000   258.000000   258.015000   365.000000   365.000000
# 75%     151.000000  1250.000000  1250.002000   710.000000   710.000000
# max     227.000000  4283.000000  4283.003000   920.000000   920.000000
#
#        warstrtmnth   warstrtday    warstrtyr   warendmnth     warenday  \
# count  1362.000000  1362.000000  1362.000000  1362.000000  1362.000000
# mean      7.182085    13.585169  1930.182085     6.530837    16.422907
# std       3.312174     9.067411    36.050324     3.001494     9.674208
# min       1.000000     1.000000  1823.000000     1.000000     1.000000
# 25%       5.000000     5.000000  1914.000000     4.000000     7.000000
# 50%       7.000000    12.000000  1941.000000     7.000000    15.000000
# 75%      10.000000    22.000000  1951.000000     9.000000    27.000000
# max      12.000000    31.000000  2003.000000    12.000000    31.000000
#
#           warendyr         year      warolea      waroleb  wardyadrolea  \
# count  1362.000000  1362.000000  1362.000000  1362.000000   1362.000000
# mean   1932.798825  1931.487518     2.475037     2.460352      2.035242
# std      36.639344    36.344141     1.163886     1.151416      0.999746
# min    1823.000000  1823.000000     1.000000     1.000000      1.000000
# 25%    1918.000000  1916.000000     1.000000     1.000000      1.000000
# 50%    1944.000000  1942.000000     2.500000     3.000000      3.000000
# 75%    1953.000000  1952.000000     4.000000     3.000000      3.000000
# max    2003.000000  2003.000000     4.000000     4.000000      3.000000
#
#        wardyadroleb     outcomea       batdtha       batdthb  changes_1  \
# count   1362.000000  1360.000000  1.348000e+03  1.348000e+03  85.000000
# mean       1.961087     2.007353  5.369196e+05  5.296547e+05   6.294118
# std        0.999242     0.883137  1.199331e+06  1.200440e+06   3.228679
# min        1.000000     1.000000  0.000000e+00  0.000000e+00   1.000000
# 25%        1.000000     1.000000  2.500000e+03  2.100000e+03   2.000000
# 50%        1.000000     2.000000  5.448700e+04  4.489050e+04   7.000000
# 75%        3.000000     3.000000  4.226120e+05  4.226120e+05   7.000000
# max        3.000000     3.000000  7.500000e+06  7.500000e+06  11.000000
#
#        changes_2       batdths      durindx                War_Length  \
# count        0.0  1.346000e+03  1362.000000                      1362
# mean         NaN  1.068156e+06     2.317181  938 days 15:33:34.096916
# std          NaN  1.767661e+06     1.668082  824 days 14:53:32.266406
# min          NaN  2.000000e+02     1.000000           0 days 00:00:00
# 25%          NaN  1.350000e+04     1.000000         199 days 06:00:00
# 50%          NaN  3.172960e+05     2.000000         889 days 00:00:00
# 75%          NaN  1.270000e+06     3.000000        1346 days 00:00:00
# max          NaN  1.100000e+07    11.000000        3734 days 00:00:00
#
#        diff_in_days
# count   1362.000000
# mean     938.648311
# std      824.620512
# min        0.000000
# 25%      199.250000
# 50%      889.000000
# 75%     1346.000000
# max     3734.000000

# %%
df.loc[df["batdtha"] < 0]
# Out:
# Empty DataFrame
# Columns: [warnum, disno, dyindex, statea, stateb, warstrtmnth, warstrtday, warstrtyr, warendmnth, warenday, warendyr, year, warolea, waroleb, wardyadrolea, wardyadroleb, outcomea, batdtha, batdthb, changes_1, changes_2, batdths, durindx, War_Start_Month_Str, War_Start_Day_Str, War_Start_Year_Str, Dash, Dash2, WarSDate, War_Start_DT, War_End_Month_Str, War_End_Day_Str, War_End_Year_Str, WarEndDate, W_End_Dt, War_Length, diff_in_days]
# Index: []

# %%
df["batdtha"].hist(bins=15)

# %%
df["batdthb"].hist(bins=15)

# %%
df['batdtha'].isna().sum() # We can see we have to deal with null values for this column
# Out:
# 14

# %%
df['batdthb'].isna().sum() #Same as above
# Out:
# 14

# %%
df.loc[df['batdtha'].isna()]
# Out:
#       warnum  disno   dyindex  statea  stateb  warstrtmnth  warstrtday  \
# 821      139   1694  1694.001     800     710            5          10
# 852                1944    -     -   9-1-1944   1944-09-01                 1
# 853                1944    -     -   9-1-1944   1944-09-01                 1
# 1250               1974    -     -  7-23-1974   1974-07-23                 8
# 1251               1974    -     -  7-23-1974   1974-07-23                 8
# 1260               1987    -     -   8-4-1987   1987-08-04                 6
# 1261               1987    -     -   8-4-1987   1987-08-04                 6
# 1264               1987    -     -   8-4-1987   1987-08-04                 6
# 1265               1987    -     -   8-4-1987   1987-08-04                 6
#
#      War_End_Day_Str War_End_Year_Str WarEndDate   W_End_Dt War_Length  \
# 821               17             1942  5-17-1942 1942-05-17     7 days
# 823               17             1942  5-17-1942 1942-05-17     7 days
# 834               24             1940  9-24-1940 1940-09-24     2 days
# 835               24             1940  9-24-1940 1940-09-24     2 days
# 850               20             1945  1-20-1945 1945-01-20   141 days
# 851               20             1945  1-20-1945 1945-01-20   141 days
# 852               20             1945  1-20-1945 1945-01-20   141 days
# 853               20             1945  1-20-1945 1945-01-20   141 days
# 1250              16             1978  8-16-1978 1978-08-16  1485 days
# 1251              16             1978  8-16-1978 1978-08-16  1485 days
# 1260              27             1988  6-27-1988 1988-06-27   328 days
# 1261              27             1988  6-27-1988 1988-06-27   328 days
# 1264              27             1988  6-27-1988 1988-06-27   328 days
# 1265              27             1988  6-27-1988 1988-06-27   328 days
#
#       diff_in_days
# 821              7
# 823              7
# 834              2
# 835              2
# 850            141
# 851            141
# 852            141
# 853            141
# 1250          1485
# 1251          1485
# 1260           328
# 1261           328
# 1264           328
# 1265           328

# %%
mode_bat_dtha = df["batdtha"].mode()

mode_bat_dtha = mode_bat_dtha.values[0]

# %%
type(mode_bat_dtha)
# Out:
# numpy.float64

# %%
mode_bat_dthb = df["batdthb"].mode()
mode_bat_dthb = mode_bat_dthb.values[0]

# %%
df["batdtha"] = df["batdtha"].fillna(
    mode_bat_dtha
)  # need to assign to column to overwrite. Without overwiting its just showing.

# %%
df["batdthb"] = df["batdthb"].fillna(
    mode_bat_dthb
)  # Given how skewed much of the data is, I chose to to use the mode
# to fill in the missing values

# %%
raw_differences = df["batdtha"] - df["batdthb"]
df["diff_in_deaths"] = raw_differences
# Now that the null values have been filled, I make a new columns that captures the differences in casualties

# %%
df["total_battle_dths"] = (
    df["batdtha"] + df["batdthb"]
)  # I also make a column for total battle deaths.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1362 entries, 0 to 1363
# Data columns (total 39 columns):
# warnum                 1362 non-null int64
# disno                  1362 non-null int64
# dyindex                1362 non-null float64
# statea                 1362 non-null int64
# stateb                 1362 non-null int64
# warstrtmnth            1362 non-null int64
# warstrtday             1362 non-null int64
# warstrtyr              1362 non-null int64
# warendmnth             1362 non-null int64
# warenday               1362 non-null int64
# warendyr               1362 non-null int64
# year                   1362 non-null int64
# warolea                1362 non-null int64
# waroleb                1362 non-null int64
# wardyadrolea           1362 non-null int64
# wardyadroleb           1362 non-null int64
# outcomea               1360 non-null float64
# batdtha                1362 non-null float64
# batdthb                1362 non-null float64
# changes_1              85 non-null float64
# changes_2              0 non-null float64
# batdths                1346 non-null float64
# durindx                1362 non-null int64
# War_Start_Month_Str    1362 non-null object
# War_Start_Day_Str      1362 non-null object
# War_Start_Year_Str     1362 non-null object
# Dash                   1362 non-null object
# Dash2                  1362 non-null object
# WarSDate               1362 non-null object
# War_Start_DT           1362 non-null datetime64[ns]
# War_End_Month_Str      1362 non-null object
# War_End_Day_Str        1362 non-null object
# War_End_Year_Str       1362 non-null object
# WarEndDate             1362 non-null object
# W_End_Dt               1362 non-null datetime64[ns]
# War_Length             1362 non-null timedelta64[ns]
# diff_in_days           1362 non-null int64
# diff_in_deaths         1362 non-null float64
# total_battle_dths      1362 non-null float64
# dtypes: datetime64[ns](2), float64(9), int64(17), object(10), timedelta64[ns](1)
# memory usage: 425.6+ KB

# %%
df['diff_in_deaths'].hist(bins=10)

# %%
df.corr() # As we can see, using a table is a bit of an eyesore fo examining correlations.
# Out:
#                      warnum     disno   dyindex    statea    stateb  \
# warnum             1.000000  0.291747  0.291744  0.425302  0.425302
# disno              0.291747  1.000000  1.000000 -0.048421 -0.048421
# dyindex            0.291744  1.000000  1.000000 -0.048429 -0.048429
# statea             0.425302 -0.048421 -0.048429  1.000000  0.342502
# stateb             0.425302 -0.048421 -0.048429  0.342502  1.000000
# warstrtmnth        0.040938 -0.121438 -0.121434  0.058351  0.059069
# warstrtday        -0.109482  0.064510  0.064508 -0.077697 -0.080851
# warstrtyr          0.994725  0.265305  0.265302  0.443055  0.443055
# warendmnth        -0.040594 -0.264591 -0.264568 -0.049528 -0.044394
# warenday           0.312575 -0.158304 -0.158297  0.288053  0.291980
# warendyr           0.991655  0.249183  0.249180  0.451741  0.451741
# year               0.993093  0.257142  0.257140  0.447428  0.447428
# warolea            0.041400 -0.104491 -0.104485 -0.069130  0.049031
# waroleb            0.030218 -0.104444 -0.104439  0.050490 -0.070689
# wardyadrolea       0.032801 -0.011994 -0.011994  0.120198 -0.036591
# wardyadroleb      -0.033472  0.015322  0.015323 -0.122894  0.033443
# outcomea           0.012238 -0.000166 -0.000168  0.095371 -0.066633
# batdtha            0.074996 -0.124799 -0.124794 -0.102644 -0.113315
# batdthb            0.067519 -0.129115 -0.129110 -0.120759 -0.110742
# changes_1         -0.140335  0.617408  0.617405  0.172829  0.159722
# changes_2               NaN       NaN       NaN       NaN       NaN
# batdths            0.097719 -0.174888 -0.174881 -0.152294 -0.152294
# durindx            0.149012 -0.126519 -0.126520  0.172543  0.172543
# diff_in_days       0.204943 -0.209414 -0.209413  0.247989  0.248551
# diff_in_deaths     0.005471  0.003281  0.003281  0.013463 -0.001819
# total_battle_dths  0.096804 -0.172479 -0.172472 -0.151759 -0.152195
#
#                    warstrtmnth  warstrtday  warstrtyr  warendmnth  warenday  \
# warnum                0.040938   -0.109482   0.994725   -0.040594  0.312575
# disno                -0.121438    0.064510   0.265305   -0.264591 -0.158304
# dyindex              -0.121434    0.064508   0.265302   -0.264568 -0.158297
# statea                0.058351   -0.077697   0.443055   -0.049528  0.288053
# stateb                0.059069   -0.080851   0.443055   -0.044394  0.291980
# warstrtmnth           1.000000   -0.023318   0.038009    0.189304 -0.002955
# warstrtday           -0.023318    1.000000  -0.134645    0.015521 -0.041546
# warnum                -0.033472  0.012238  0.074996  0.067519  -0.140335
# disno                  0.015322 -0.000166 -0.124799 -0.129115   0.617408
# dyindex                0.015323 -0.000168 -0.124794 -0.129110   0.617405
# statea                -0.122894  0.095371 -0.102644 -0.120759   0.172829
# stateb                 0.033443 -0.066633 -0.113315 -0.110742   0.159722
# warstrtmnth            0.044545  0.009098  0.009888  0.003954  -0.017050
# warstrtday             0.034142 -0.017154 -0.006230  0.004934   0.158909
# warstrtyr             -0.036293  0.014328  0.079997  0.071060  -0.111390
# warendmnth             0.019876 -0.014784  0.024532  0.031755  -0.471653
# warenday              -0.031056 -0.003631 -0.046981 -0.048771   0.120877
# warendyr              -0.038907  0.015138  0.088318  0.079093  -0.133098
# year                  -0.037635  0.014463  0.084182  0.075125  -0.122471
# warolea               -0.145828 -0.150230 -0.016450  0.168961  -0.123441
# waroleb                0.136279  0.140745  0.177582 -0.042997  -0.083905
# wardyadrolea          -0.989342  0.166390  0.112232 -0.121763   0.019407
# wardyadroleb           1.000000 -0.171446 -0.114179  0.126988  -0.019407
# outcomea              -0.171446  1.000000  0.043063 -0.044709   0.020390
# batdtha               -0.114179  0.043063  1.000000  0.083622  -0.357616
# batdthb                0.126988 -0.044709  0.083622  1.000000  -0.397099
# changes_1             -0.019407  0.020390 -0.357616 -0.397099   1.000000
# changes_2                   NaN       NaN       NaN       NaN        NaN
# batdths                0.008559 -0.001159  0.735867  0.736445  -0.575553
# durindx               -0.036230  0.012389  0.102616  0.098195  -0.221872
# diff_in_days          -0.055822  0.014306  0.156970  0.151322  -0.400110
# diff_in_deaths        -0.178147  0.064901  0.676500 -0.677293   0.028240
# total_battle_dths      0.008782 -0.001146  0.735770  0.736387  -0.580527
#
#                    changes_2   batdths   durindx  diff_in_days  \
# warnum                   NaN  0.097719  0.149012      0.204943
# disno                    NaN -0.174888 -0.126519     -0.209414
# dyindex                  NaN -0.174881 -0.126520     -0.209413
# statea                   NaN -0.152294  0.172543      0.247989
# stateb                   NaN -0.152294  0.172543      0.248551
# warstrtmnth              NaN  0.008888  0.088349      0.021652
# warstrtday               NaN -0.001381 -0.125662     -0.190142
# warstrtyr                NaN  0.103705  0.163255      0.225222
# warendmnth               NaN  0.037881 -0.139316     -0.105020
# warenday                 NaN -0.064998  0.114935      0.187305
# warendyr                 NaN  0.114738  0.203736      0.283849
# year                     NaN  0.109258  0.184042      0.254724
# warolea                  NaN  0.104878  0.004838      0.006255
# waroleb                  NaN  0.091669 -0.009132      0.003401
# wardyadrolea             NaN -0.006313  0.038232      0.058963
# wardyadroleb             NaN  0.008559 -0.036230     -0.055822
# outcomea                 NaN -0.001159  0.012389      0.014306
# batdtha                  NaN  0.735867  0.102616      0.156970
# batdthb                  NaN  0.736445  0.098195      0.151322
# changes_1                NaN -0.575553 -0.221872     -0.400110
# changes_2                NaN       NaN       NaN           NaN
# batdths                  NaN  1.000000  0.135924      0.209352
# durindx                  NaN  0.135924  1.000000      0.675921
# diff_in_days             NaN  0.209352  0.675921      1.000000
# diff_in_deaths           NaN -0.000932  0.003192      0.004060
# total_battle_dths        NaN  1.000000  0.136405      0.209413
#
#                    diff_in_deaths  total_battle_dths
# warnum                   0.005471           0.096804
# disno                    0.003281          -0.172479
# dyindex                  0.003281          -0.172472
# statea                   0.013463          -0.151759
# stateb                  -0.001819          -0.152195
# warstrtmnth              0.004378           0.009400
# warstrtday              -0.008246          -0.000877
# warstrtyr                0.006546           0.102606
# warendmnth              -0.005356           0.038237
# warenday                 0.001357          -0.065043
# warendyr                 0.006754           0.113715
# year                     0.006632           0.108210
# warolea                 -0.137013           0.103659
# waroleb                  0.162885           0.091346
# wardyadrolea             0.172848          -0.006553
# wardyadroleb            -0.178147           0.008782
# outcomea                 0.064901          -0.001146
# batdtha                  0.676500           0.735770
# batdthb                 -0.677293           0.736387
# changes_1                0.028240          -0.580527
# changes_2                     NaN                NaN
# batdths                 -0.000932           1.000000
# durindx                  0.003192           0.136405
# diff_in_days             0.004060           0.209413
# diff_in_deaths           1.000000          -0.000995
# total_battle_dths       -0.000995           1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
multico_test = df[["diff_in_days", "diff_in_deaths"]].corr()
multico_test  # Wanted to ensure that these two variables were not highly correlated, thankfully they were not.
# Out:
#                 diff_in_days  diff_in_deaths
# diff_in_days         1.00000         0.00406
# diff_in_deaths       0.00406         1.00000

# %%
fig, ax = plt.subplots(figsize=(25, 30))
sns.heatmap(
    df.corr(),
    vmin=-1,
    vmax=1,
    center=0,
    annot=True,
    square=False,
    cmap=sns.color_palette("RdBu_r", 9),
)

# %%
df = df.dropna(subset=["outcomea"], axis="rows")

# %%
df
# Out:
#       warnum  disno   dyindex  statea  stateb  warstrtmnth  warstrtday  \
# 0          1     89    89.001     220     230            4           7
# 1          1     89    89.001     230     220            4           7
# 2          4    189   189.001     365     640            4          30
# 3          4    189   189.001     365     640            4          30
# 4          4    189   189.001     640     365            4          30
# 5          4    189   189.001     640     365            4          30
# 6          7   1552  1552.001       2      70            4          25
# 7          7   1552  1552.001       2      70            4          25
# 8          7   1552  1552.001      70       2            4          25
# 9          7   1552  1552.001      70       2            4          25
# 10        10     19    19.001     300     325            4           4
# 11        10     19    19.001     300     325            4           4
# 12        10     19    19.001     325     300            4           4
# 13        10     19    19.001     325     300            4           4
# 14        10     19    19.002     300     332            4           9
# 15        10     19    19.002     332     300            4           9
# 16        10     19    19.003     300     337            4           9
# 17        10     19    19.003     337     300            4           9
# 18        13    375   375.003     255     390            4          10
# 19        13    375   375.003     255     390            4          10
# 20        13    375   375.003     390     255            4          10
# 21        13    375   375.003     390     255            4          10
# 22        16    175   175.001     220     327            4          30
# 23        16    175   175.001     327     220            4          30
# 24        16    175   175.002     300     327            5           8
# 25        16    175   175.002     327     300            5           8
# 26        16    175   175.003     327     329            5           8
# 27        16    175   175.003     329     327            5           8
# 28        19   1528  1528.001     140     160            7          19
# 29        19   1528  1528.001     140     160            7          19
# ...      ...    ...       ...     ...     ...          ...         ...
# 1334     211   3957  3957.020     645     651            2          24
# 1335     211   3957  3957.020     651     645            2          24
# 1344       1998           6        18      2000  1998        3        1
# 1345       1998           6        18      2000  1999        3        1
# 1346       1998           6        18      2000  2000        3        1
# 1347       1998           6        18      2000  1998        1        3
# 1348       1998           6        18      2000  1999        1        3
# 1349       1998           6        18      2000  2000        1        3
# 1350       1999           6        10      1999  1999        1        3
# 1351       1999           6        10      1999  1999        3        1
# 1352       1999           7        17      1999  1999        3        1
# 1353       1999           7        17      1999  1999        1        3
# 1354       2001          11        15      2001  2001        1        3
# 1355       2001          11        15      2001  2001        3        1
# 1356       2001          11        15      2001  2001        2        3
# 1357       2001          11        15      2001  2001        3        2
# 1358       2003           5         2      2003  2003        1        3
# 1359       2003           5         2      2003  2003        3        1
# 1360       2003           5         2      2003  2003        1        3
# 1361       2003           5         2      2003  2003        3        1
# 1362       2003           5         2      2003  2003        3        1
# 1363       2003           5         2      2003  2003        1        3
#
#       wardyadrolea  wardyadroleb  outcomea  batdtha  batdthb  changes_1  \
# 0                1             3       1.0    400.0    600.0        NaN
# 1                3             1       3.0    600.0    400.0        NaN
# 2                1             3       1.0  80000.0  50000.0        NaN
# 3                1             3       1.0  80000.0  50000.0        NaN
# 4                3             1       3.0  50000.0  80000.0        NaN
# 5                3             1       3.0  50000.0  80000.0        NaN
# 6                1             3       1.0  13283.0   6000.0        NaN
# 7                1             3       1.0  13283.0   6000.0        NaN
# 8                3             1       3.0   6000.0  13283.0        NaN
# 9                3             1       3.0   6000.0  13283.0        NaN
# 10               3             1       1.0   3927.0   3400.0        7.0
# 11               3             1       1.0   3927.0   3400.0        7.0
# 12               1             3       3.0   3400.0   3927.0        7.0
# 13               1             3       3.0   3400.0   3927.0        7.0
# 14               3             1       1.0   3927.0    100.0        7.0
# 15               1             3       3.0    100.0   3927.0        7.0
# 16               3             1       1.0   3927.0    100.0        7.0
# 17               1             3       3.0    100.0   3927.0        7.0
# 18               1             3       2.0   2500.0   3500.0        NaN
# 19               1             3       2.0   2500.0   3500.0        NaN
# 20               3             1       2.0   3500.0   2500.0        NaN
# 21               3             1       2.0   3500.0   2500.0        NaN
# 22               1             3       1.0   1000.0   1400.0        NaN
# 23               3             1       3.0   1400.0   1000.0        NaN
# 24               1             3       1.0    100.0   1400.0        NaN
# 25               3             1       3.0   1400.0    100.0        NaN
# 26               3             1       3.0   1400.0    100.0        NaN
# 27               1             3       1.0    100.0   1400.0        NaN
# 28               1             3       1.0    500.0    800.0        NaN
# 29               1             3       1.0    500.0    800.0        NaN
# ...            ...           ...       ...      ...      ...        ...
# 1334             3             1       3.0  40000.0     14.0        NaN
# 1335             1             3       1.0     14.0  40000.0        NaN
# 1336             3             1       3.0  40000.0      0.0        NaN
# 1337             1             3       1.0      0.0  40000.0        NaN
# 1338             3             1       3.0  40000.0     44.0        NaN
# 1339             1             3       1.0     44.0  40000.0        NaN
# 1340             1             3       1.0   5500.0   8500.0        NaN
# 1341             1             3       1.0   5500.0   8500.0        NaN
# 1342             3             1       3.0   8500.0   5500.0        NaN
# 1343             3             1       3.0   8500.0   5500.0        NaN
# 1344             3             1       2.0  70000.0  50000.0        NaN
# 1345             3             1       2.0  70000.0  50000.0        NaN
# 1346             3             1       2.0  70000.0  50000.0        NaN
# 1347             1             3       2.0  50000.0  70000.0        NaN
# 1348             1             3       2.0  50000.0  70000.0        NaN
# 1349             1             3       2.0  50000.0  70000.0        NaN
# 1350             1             3       1.0      2.0   5000.0        NaN
# 1351             3             1       3.0   5000.0      2.0        NaN
# 1352             3             1       1.0    474.0    698.0        NaN
# 1353             1             3       3.0    698.0    474.0        NaN
# 1354             1             3       1.0      2.0   4000.0        NaN
# 1355             3             1       3.0   4000.0      2.0        NaN
# 1356             1             3       1.0      0.0   4000.0        NaN
# 1357             3             1       3.0   4000.0      0.0        NaN
# 1358             1             3       1.0    140.0   7000.0        NaN
# 1359             3             1       3.0   7000.0    140.0        NaN
# 1360             1             3       1.0     33.0   7000.0        NaN
# 1361             3             1       3.0   7000.0     33.0        NaN
# 1362             3             1       3.0   7000.0      0.0        NaN
# 1363             1             3       1.0      0.0   7000.0        NaN
#
#       changes_2   batdths  durindx War_Start_Month_Str War_Start_Day_Str  \
# 0           NaN    1000.0        1                   4                 7
# 1           NaN    1000.0        1                   4                 7
# 2           NaN  130000.0        1                   4                30
# 3           NaN  130000.0        2                   4                30
# 4           NaN  130000.0        2                   4                30
# 5           NaN  130000.0        1                   4                30
# 6           NaN   19283.0        1                   4                25
# 7           NaN   19283.0        2                   4                25
# 8           NaN   19283.0        1                   4                25
# 9           NaN   19283.0        2                   4                25
# 10          NaN    7327.0        2                   4                 4
# 11          NaN    7327.0        1                   4                 4
# 12          NaN    7327.0        2                   4                 4
# 13          NaN    7327.0        1                   4                 4
# 14          NaN    4027.0        1                   4                 9
# 15          NaN    4027.0        1                   4                 9
# 16          NaN    4027.0        1                   4                 9
# 17          NaN    4027.0        1                   4                 9
# 18          NaN    6000.0        2                   4                10
# 19          NaN    6000.0        1                   4                10
# 20          NaN    6000.0        1                   4                10
# 21          NaN    6000.0        2                   4                10
# 22          NaN    2400.0        1                   4                30
# 23          NaN    2400.0        1                   4                30
# 24          NaN    1500.0        1                   5                 8
# 25          NaN    1500.0        1                   5                 8
# 26          NaN    1500.0        1                   5                 8
# 27          NaN    1500.0        1                   5                 8
# 28          NaN    1300.0        2                   7                19
# 29          NaN    1300.0        1                   7                19
# ...         ...       ...      ...                 ...               ...
# 1334        NaN   40014.0        1                   2                24
# 1335        NaN   40014.0        1                   2                24
# 1336        NaN   40000.0        1                   2                24
# 1337        NaN   40000.0        1                   2                24
# 1338        NaN   40044.0        1                   1                17
# 1339        NaN   40044.0        1                   1                17
# 1340        NaN   14000.0        2                   2                 6
# 1341        NaN   14000.0        1                   2                 6
# 1342        NaN   14000.0        1                   2                 6
# 1343        NaN   14000.0        2                   2                 6
# 1344        NaN  120000.0        2                   5                 6
# 1345        NaN  120000.0        1                   5                 6
# 1346        NaN  120000.0        3                   5                 6
# 1347        NaN  120000.0        1                   5                 6
# 1348        NaN  120000.0        3                   5                 6
# 1349        NaN  120000.0        2                   5                 6
# 1350        NaN    5002.0        1                   3                24
# 1351        NaN    5002.0        1                   3                24
# 1354            61         -3998.0             4002.0
# 1355            61          3998.0             4002.0
# 1356            61         -4000.0             4000.0
# 1357            61          4000.0             4000.0
# 1358            44         -6860.0             7140.0
# 1359            44          6860.0             7140.0
# 1360            44         -6967.0             7033.0
# 1361            44          6967.0             7033.0
# 1362            44          7000.0             7000.0
# 1363            44         -7000.0             7000.0
#
# [1360 rows x 39 columns]

# %%
df = df.select_dtypes(exclude=[object])

# %%
# Below, I eliminate a few superfluous columns that I won't be using.

# %%
df = df.drop(
    columns=[
        "warnum",
        "disno",
        "dyindex",
        "changes_1",
        "changes_2",
        "War_Start_DT",
        "W_End_Dt",
        "War_Length",
        "batdths",
    ]
)

# %%
df.to_csv("clean_war_data.csv", index=False)

# %% [markdown]
# # Reading In the Clean Dataset Alongside of the Second One

# %%
clean_war_set = pd.read_csv("clean_war_data.csv")  # upload clean war dataset

# %%
NMC_Data = pd.read_csv(
    "NMC_5_0.csv"
)  # loads national material capabilities dataset. Gives more granular understanding of
# state capabilities in the form of military expenditures, military personnel available, total population, urban population,
# energy use, Iron and Steel production, as well as a composite score of each.

# %%
NMC_Data.head()
# Out:
#   stateabb  ccode  year  milex  milper  irst  pec    tpop   upop      cinc  \
# 0      USA      2  1816   3823      17    80  254  8659.0  101.0  0.039698
# 1      USA      2  1817   2466      15    80  277  8899.0  106.0  0.035817
# 2      USA      2  1818   1910      14    90  302  9139.0  112.0  0.036126
# 3      USA      2  1819   2301      13    90  293  9379.0  118.0  0.037133
# 4      USA      2  1820   1556      15   110  303  9618.0  124.0  0.037087
#
#    version
# 0     2011
# 1     2011
# 2     2011
# 3     2011
# 4     2011

# %%
df.info()  # At first glance, it looks as if there is no missing data, bu we need to do more digging to be sure.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1360 entries, 0 to 1363
# Data columns (total 20 columns):
# statea               1360 non-null int64
# stateb               1360 non-null int64
# warstrtmnth          1360 non-null int64
# warstrtday           1360 non-null int64
# warstrtyr            1360 non-null int64
# warendmnth           1360 non-null int64
# warenday             1360 non-null int64
# warendyr             1360 non-null int64
# year                 1360 non-null int64
# warolea              1360 non-null int64
# waroleb              1360 non-null int64
# wardyadrolea         1360 non-null int64
# wardyadroleb         1360 non-null int64
# outcomea             1360 non-null float64
# batdtha              1360 non-null float64
# batdthb              1360 non-null float64
# durindx              1360 non-null int64
# diff_in_days         1360 non-null int64
# diff_in_deaths       1360 non-null float64
# total_battle_dths    1360 non-null float64
# dtypes: float64(5), int64(15)
# memory usage: 223.1 KB

# %%
NMC_Data.shape #The NMC dataset seems to have many more rows and fewer columns
# Out:
# (15171, 11)

# %% [markdown]
# # Data Cleaning, Transformation, and Exploration for the Second Dataset

# %%
NMC_Data = NMC_Data.rename(
    columns={
        "ccode": "statea",
        "milex": "defensebudget",
        "milper": "milsize",
        "irst": "IronSteelProduct",
        "pec": "EnergyUse",
        "tpop": "totalpop",
        "upop": "urbanpop",
        "cinc": "CINCscore",
    }
)
# Changing column labels to make the dataset more readable and less awkward to use

# %%
fig, ax = plt.subplots(
    figsize=(25, 30)
)  # correlation matrix to see how the variables are related to one another. Powerful tool to uncover potential multi-collinearity.
sns.heatmap(
    NMC_Data.corr(),
    vmin=-1,
    vmax=1,
    center=0,
    square=True,
    annot=True,
    cmap=sns.color_palette("RdBu_r", 5),
)

# %%
# As we can see in the above heatmap, multi-collinearity could be a problem if we choose to use each column as an independent
# variable.

# %%
test = NMC_Data[(NMC_Data < 0).any(axis=1)]
test.sample(
    10
)  # As this cell shows, we might have have some problems with missing variables. -9 is the same as missing value
# according to the codebook that came with the NMC dataset. This means we need to additional cleaning.
# Out:
#       stateabb  statea  year  defensebudget  milsize  IronSteelProduct  \
# 10088      KEN     501  1973          36000        8                 0
# 3985       IRE     205  1976         129697       14                58
# 6336       CZE     315  1955         825411      250              4474
# 7854       RUS     365  2003       65200000      961             61450
# 8607       DEN     390  1917          11589       16                 0
# 6604       ITA     325  2006       33289000      191             31624
# 1825       COS      94  1981          21304        6                 0
# 7510       MLD     359  1991         875500       -9               618
# 14613      INS     850  1955         339721      199                 0
# 7658       ROM     360  2004        1530000      101              6042
#
#        EnergyUse  totalpop  urbanpop  CINCscore  version
# 10088       9970   12504.0     931.0   0.001002     2011
# 3985        4541    3228.0     678.0   0.000500     2011
# 6336       40506   13093.0    1822.0   0.009978     2011
# 7854     1119895  144880.0   50680.0   0.049705     2011
# 8607        2216    2970.0     529.0   0.001684     2011
# 6604      313646   59078.0   23137.0   0.017189     2011
# 1825        1856    2271.0     262.0   0.000200     2011
# 7510          -9    4363.0    1150.0   0.000910     2011
# 14613      19366   86552.0    6638.0   0.011914     2011
# 7658       67250   22158.0    2554.0   0.003502     2011

# %%
# Next few steps show how big the missing data problem is for each column.

# %%
missing_def = NMC_Data["defensebudget"] < 0
missing_def.value_counts(
    normalize=True
)  # Over 13 percent of defense budget values are missing
# Out:
# False    0.863885
# True     0.136115
# Name: defensebudget, dtype: float64

# %%
missing_mil_size = NMC_Data["milsize"] < 0
missing_mil_size.value_counts(
    normalize=True
)  # sligty under 3 percent of values missing
# Out:
# False    0.972447
# True     0.027553
# Name: milsize, dtype: float64

# %%
missing_iron_steel = NMC_Data["IronSteelProduct"] < 0
missing_iron_steel.value_counts(
    normalize=True
)  # almost two-tenths of a percent missing
# Out:
# False    0.998286
# True     0.001714
# Name: IronSteelProduct, dtype: float64

# %%
missing_energy_use = NMC_Data["EnergyUse"] < 0
missing_energy_use.value_counts(
    normalize=True
)  # A little over 3 percent of values missing
# Out:
# False    0.969284
# True     0.030716
# Name: EnergyUse, dtype: float64

# %%
missing_total_population = NMC_Data["totalpop"] < 0
missing_total_population.value_counts(normalize=True)  # No values missing
# Out:
# False    1.0
# Name: totalpop, dtype: float64

# %%
missing_urban_population = NMC_Data["urbanpop"] < 0
missing_urban_population.value_counts(
    normalize=True
)  # A little over four-tenths of values missing
# Out:
# False    0.995518
# True     0.004482
# Name: urbanpop, dtype: float64

# %%
missing_CINC = NMC_Data["CINCscore"] < 0
missing_CINC.value_counts(normalize=True)  # no values missing
# Out:
# False    1.0
# Name: CINCscore, dtype: float64

# %%
# The next step focuses on checking the distribution of the data to get an idea as what values could potentially be used
# to fill in the missing data and inform our choice of models and tests

# %%
NMC_Data["defensebudget"].hist(bins=10)
NMC_Data["defensebudget"].describe()
# Out:
# count    1.517100e+04
# mean     2.589148e+06
# std      2.069972e+07
# min     -9.000000e+00
# 25%      9.825000e+02
# 50%      2.720000e+04
# 75%      3.460000e+05
# max      6.936000e+08
# Name: defensebudget, dtype: float64

# %%
NMC_Data["milsize"].hist(bins=20)
NMC_Data["milsize"].describe()
# Out:
# count    15171.000000
# mean       158.563641
# std        516.542089
# min         -9.000000
# 25%          5.000000
# 50%         24.000000
# 75%        107.000000
# max      12500.000000
# Name: milsize, dtype: float64

# %%
NMC_Data["IronSteelProduct"].hist(bins=30)
NMC_Data["IronSteelProduct"].describe()
# Out:
# count     15171.000000
# mean       3211.944829
# std       18133.831812
# min          -9.000000
# 25%           0.000000
# 50%           0.000000
# 75%         428.000000
# max      731040.000000
# Name: IronSteelProduct, dtype: float64

# %%
NMC_Data["EnergyUse"].hist(bins=30)
NMC_Data["EnergyUse"].describe()
# Out:
# count    1.517100e+04
# mean     4.930146e+04
# std      2.313872e+05
# min     -9.000000e+00
# 25%      6.000000e+01
# 50%      2.214000e+03
# 75%      1.829800e+04
# max      5.333707e+06
# Name: EnergyUse, dtype: float64

# %%
NMC_Data["urbanpop"].hist(bins=30)
NMC_Data["urbanpop"].describe()
# Out:
# count     15171.000000
# mean       5019.168324
# std       20241.512208
# min          -9.000000
# 25%         114.000000
# 50%         668.000000
# 75%        2596.500000
# max      612933.000000
# Name: urbanpop, dtype: float64

# %%
NMC_Data["CINCscore"].hist(bins=25)
NMC_Data["CINCscore"].describe()
# Out:
# count    1.517100e+04
# mean     1.330652e-02
# std      3.718941e-02
# min      2.440000e-07
# 25%      4.517000e-04
# 50%      1.703400e-03
# 75%      6.944350e-03
# max      3.838635e-01
# Name: CINCscore, dtype: float64

# %%
# As we can see in the cells above, the data is extremely skewed. All of the distributions have a strong positive skew.

# %%
NMC_Data = NMC_Data.replace(
    -9, np.nan
)  # Replace the dataset's NA value, -9, with a negative value that Pandas can use

# %%
NMC_Data["defensebudget"].sample(
    30
)  # As we can see, the previous cell was able to replace -9 with usable null values
# Out:
# 1546            NaN
# 10055       74130.0
# 5447         3379.0
# 2710      1372098.0
# 10644      456298.0
# 3430      4274000.0
# 9738       253000.0
# 11431      346000.0
# 3680        34905.0
# 9620        16762.0
# 8            1261.0
# 8872         6000.0
# 15109           0.0
# 8104      1585000.0
# 6591     20570000.0
# 12237        6906.0
# 12745      119760.0
# 7742        34531.0
# 12842       42422.0
# 9083         1945.0
# 1214      3123000.0
# 1189       824147.0
# 4341       383680.0
# 13661           NaN
# 7081       689176.0
# 6032         6175.0
# 5812            NaN
# 265       8830000.0
# 12872      120000.0
# 5158         1104.0
# Name: defensebudget, dtype: float64

# %%
defense_mode = NMC_Data["defensebudget"].mode()
defense_mode = defense_mode.values[
    0
]  # 2nd line of code converts to int64 object to be usable. Repeat for next few cells.

# %%
milsize_mode = NMC_Data["milsize"].mode()
milsize_mode = milsize_mode.values[0]

# %%
Iron_Steel_Mode = NMC_Data["IronSteelProduct"].mode()
Iron_Steel_Mode = Iron_Steel_Mode.values[0]

# %%
energy_use_mode = NMC_Data["EnergyUse"].mode()
energy_use_mode = energy_use_mode.values[0]

# %%
urban_pop_mode = NMC_Data["urbanpop"].mode()
urban_pop_mode = urban_pop_mode.values[0]

# %%
total_pop_mode = NMC_Data["totalpop"].mode()
total_pop_mode = total_pop_mode.values[0]

# %%
cinc_score_mode = NMC_Data["CINCscore"].mode()
cinc_score_mode = cinc_score_mode.values[0]

# %%
# So far, missing values are not that big of a concern for most independent variables. Given how skewed the values are,
# it might make more sense to use the mode of each coumns to fill in the missing values without it heavily impacting the
# analysis.

# %%
NMC_Data["defensebudget"] = NMC_Data["defensebudget"].fillna(value=defense_mode)

# %%
NMC_Data["milsize"] = NMC_Data["milsize"].fillna(value=milsize_mode)

# %%
NMC_Data["IronSteelProduct"] = NMC_Data["IronSteelProduct"].fillna(
    value=Iron_Steel_Mode
)

# %%
NMC_Data["EnergyUse"] = NMC_Data["EnergyUse"].fillna(value=energy_use_mode)

# %%
NMC_Data["urbanpop"] = NMC_Data["urbanpop"].fillna(value=urban_pop_mode)

# %%
NMC_Data["totalpop"] = NMC_Data["totalpop"].fillna(value=total_pop_mode)

# %%
NMC_Data["CINCscore"] = NMC_Data["CINCscore"].fillna(value=cinc_score_mode)

# %%
Intermediate_DS = pd.merge(
    NMC_Data, clean_war_set, on=["statea", "year"], sort=True
)  # Merge the MNC data with the clean
# war dataset based on the values for state a and the year of the conflict

# %%
Intermediate_DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1360 entries, 0 to 1359
# Data columns (total 29 columns):
# stateabb             1360 non-null object
# statea               1360 non-null int64
# year                 1360 non-null int64
# defensebudget        1360 non-null float64
# milsize              1360 non-null float64
# IronSteelProduct     1360 non-null float64
# EnergyUse            1360 non-null float64
# totalpop             1360 non-null float64
# urbanpop             1360 non-null float64
# CINCscore            1360 non-null float64
# version              1360 non-null int64
# stateb               1360 non-null int64
# warstrtmnth          1360 non-null int64
# warstrtday           1360 non-null int64
# warstrtyr            1360 non-null int64
# warendmnth           1360 non-null int64
# warenday             1360 non-null int64
# warendyr             1360 non-null int64
# warolea              1360 non-null int64
# waroleb              1360 non-null int64
# wardyadrolea         1360 non-null int64
# wardyadroleb         1360 non-null int64
# outcomea             1360 non-null float64
# batdtha              1360 non-null float64
# batdthb              1360 non-null float64
# durindx              1360 non-null int64
# diff_in_days         1360 non-null int64
# diff_in_deaths       1360 non-null float64
# total_battle_dths    1360 non-null float64
# dtypes: float64(12), int64(16), object(1)
# memory usage: 318.8+ KB

# %%
Intermediate_DS.shape
# Out:
# (1360, 29)

# %%
fig, ax = plt.subplots(
    figsize=(30, 35)
)  # correlation matrix to see how the variables are related to one another. Powerful tool to uncover potential multi-collinearity.
sns.heatmap(
    Intermediate_DS.corr(),
    vmin=-1,
    vmax=1,
    center=0,
    square=False,
    annot=True,
    cmap=sns.color_palette("RdBu_r", 5),
)

# %%
d = {"stateb": Intermediate_DS["stateb"], "year": Intermediate_DS["year"]}
tst_df = pd.DataFrame(
    data=d
)  # Since the dataset I plan to use examines war in a dyadic context, I need CINC values in
# the table for state b and they need to align with the year of the conflict. Only then can I create an independent variable
# that measures the differences in capabiltiies between statea and stateb.

# %%
tst_df.shape
# Out:
# (1360, 2)

# %%
tst_df.head()
# Out:
#    stateb  year
# 0      70  1846
# 1      70  1847
# 2     230  1898
# 3     710  1900
# 4     255  1917

# %%
Interim_df = pd.merge(
    tst_df,
    NMC_Data,
    left_on=["stateb", "year"],
    right_on=["statea", "year"],
    how="inner",
    sort=True,
)

# %%
Interim_df.shape
# Out:
# (1360, 12)

# %%
Interim_df.head()
# Out:
#    stateb  year stateabb  statea  defensebudget  milsize  IronSteelProduct  \
# 0       2  1846      USA       2         9506.0     39.0             777.0
# 1       2  1847      USA       2         7431.0     58.0             813.0
# 2       2  1898      USA       2        60011.0    236.0           11963.0
# 3       2  1900      USA       2        41481.0    126.0           10352.0
# 4       2  1917      USA       2       658584.0    644.0           45784.0
#
#    EnergyUse  totalpop  urbanpop  CINCscore  version
# 0     4863.0   20794.0     846.0   0.082757     2011
# 1     5767.0   21406.0     918.0   0.084510     2011
# 2   207271.0   73494.0   13162.0   0.197062     2011
# 3   256081.0   76094.0   14207.0   0.187999     2011
# 4   710959.0  103268.0   25310.0   0.244028     2011

# %%
Interim_df = Interim_df.drop(
    columns=[
        "stateabb",
        "statea",
        "defensebudget",
        "milsize",
        "IronSteelProduct",
        "EnergyUse",
        "totalpop",
        "urbanpop",
    ]
)

# %%
Interim_df.head()  # Now we have the stateb country code values along with the CINCscores for stateb to merge in our final dataset
# Out:
#    stateb  year  CINCscore  version
# 0       2  1846   0.082757     2011
# 1       2  1847   0.084510     2011
# 2       2  1898   0.197062     2011
# 3       2  1900   0.187999     2011
# 4       2  1917   0.244028     2011

# %%
Interim_df.shape  # Number of rows looks good
# Out:
# (1360, 4)

# %%
Interim_df = Interim_df.rename(columns={"CINCscore": "CINC_b"})  # To avoid confusion

# %%
Comp_War_Dataset = pd.merge(
    Intermediate_DS, Interim_df, on=["year", "stateb"], how="left"
)

# %%
Comp_War_Dataset.head()  # columns look good
# Out:
#   stateabb  statea  year  defensebudget  milsize  IronSteelProduct  EnergyUse  \
# 0      USA       2  1846         9506.0     39.0             777.0     4863.0
# 1      USA       2  1847         7431.0     58.0             813.0     5767.0
# 2      USA       2  1898        60011.0    236.0           11963.0   207271.0
# 3      USA       2  1900        41481.0    126.0           10352.0   256081.0
# 4      USA       2  1900        41481.0    126.0           10352.0   256081.0
#
#    totalpop  urbanpop  CINCscore  version_x  stateb  warstrtmnth  warstrtday  \
# 0   20794.0     846.0   0.082757       2011      70            4          25
# 1   21406.0     918.0   0.084510       2011      70            4          25
# 2   73494.0   13162.0   0.197062       2011     230            5           1
# 3   76094.0   14207.0   0.187999       2011     710            6          17
# 4   76094.0   14207.0   0.187999       2011     710            6          17
#
#    warstrtyr  warendmnth  warenday  warendyr  warolea  waroleb  wardyadrolea  \
# 0       1846           9        14      1847        1        3             1
# 1       1846           9        14      1847        1        3             1
# 2       1898           6        17      1898        1        3             1
# 3       1900           8        15      1900        1        3             1
# 4       1900           8        15      1900        1        3             1
#
#    wardyadroleb  outcomea  batdtha  batdthb  durindx  diff_in_days  \
# 0             3       1.0  13283.0   6000.0        1           507
# 1             3       1.0  13283.0   6000.0        2           507
# 2             3       1.0   2910.0    775.0        1            47
# 3             3       1.0     21.0   2000.0        1            59
# 4             3       1.0     21.0   2000.0        1            59
#
#    diff_in_deaths  total_battle_dths    CINC_b  version_y
# 0          7283.0            19283.0  0.017940       2011
# 1          7283.0            19283.0  0.008620       2011
# 2          2135.0             3685.0  0.017012       2011
# 3         -1979.0             2021.0  0.119977       2011
# 4         -1979.0             2021.0  0.119977       2011

# %%
Comp_War_Dataset.shape #Looks like we have a problem with duplicate rows
# Out:
# (5700, 31)

# %%
Comp_War_Dataset = Comp_War_Dataset.drop_duplicates()

# %%
Comp_War_Dataset.shape  # Duplicate problem solved
# Out:
# (1360, 31)

# %%
Comp_War_Dataset = Comp_War_Dataset.rename(
    columns={"CINCscore": "CINC_Score_A", "CINC_b": "CINC_Score_B"}
)

# %%
Comp_War_Dataset['diff_CINC'] = Comp_War_Dataset['CINC_Score_A'] - Comp_War_Dataset['CINC_Score_B']

# %%
Comp_War_Dataset.head()  # Everything looks good. Ready to train models.
# Out:
#   stateabb  statea  year  defensebudget  milsize  IronSteelProduct  EnergyUse  \
# 0      USA       2  1846         9506.0     39.0             777.0     4863.0
# 1      USA       2  1847         7431.0     58.0             813.0     5767.0
# 2      USA       2  1898        60011.0    236.0           11963.0   207271.0
# 3      USA       2  1900        41481.0    126.0           10352.0   256081.0
# 9      USA       2  1917       658584.0    644.0           45784.0   710959.0
#
#    totalpop  urbanpop  CINC_Score_A  version_x  stateb  warstrtmnth  \
# 0   20794.0     846.0      0.082757       2011      70            4
# 1   21406.0     918.0      0.084510       2011      70            4
# 2   73494.0   13162.0      0.197062       2011     230            5
# 3   76094.0   14207.0      0.187999       2011     710            6
# 9  103268.0   25310.0      0.244028       2011     255            6
#
#    warstrtday  warstrtyr  warendmnth  warenday  warendyr  warolea  waroleb  \
# 0          25       1846           9        14      1847        1        3
# 1          25       1846           9        14      1847        1        3
# 2           1       1898           6        17      1898        1        3
# 3          17       1900           8        15      1900        1        3
# 9          27       1917          11        11      1918        4        1
#
#    wardyadrolea  wardyadroleb  outcomea   batdtha    batdthb  durindx  \
# 0             1             3       1.0   13283.0     6000.0        1
# 1             1             3       1.0   13283.0     6000.0        2
# 2             1             3       1.0    2910.0      775.0        1
# 3             1             3       1.0      21.0     2000.0        1
# 9             1             3       1.0  116516.0  1773700.0        1
#
#    diff_in_days  diff_in_deaths  total_battle_dths  CINC_Score_B  version_y  \
# 0           507          7283.0            19283.0      0.017940       2011
# 1           507          7283.0            19283.0      0.008620       2011
# 2            47          2135.0             3685.0      0.017012       2011
# 3            59         -1979.0             2021.0      0.119977       2011
# 9           502      -1657184.0          1890216.0      0.158169       2011
#
#    diff_CINC
# 0   0.064818
# 1   0.075890
# 2   0.180049
# 3   0.068021
# 9   0.085859

# %%
Comp_War_Dataset.to_csv("comp_war_data.csv", index=False)
